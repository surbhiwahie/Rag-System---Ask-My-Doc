# %%
golden_data = [
    {
        "question": "What are the symptoms of diabetes?",
        "ground_truth": "Symptoms include increased thirst, frequent urination, fatigue, blurred vision, and slow healing sores."
    },
    {
        "question": "What is insulin?",
        "ground_truth": "Insulin is a hormone produced by the pancreas that helps glucose enter cells to be used for energy."
    },
    {
        "question": "How is diabetes diagnosed?",
        "ground_truth": "Diabetes is diagnosed through blood sugar tests such as fasting glucose, HbA1c, or oral glucose tolerance test."
    },
    {
        "question": "Does physical activity help diabetes?",
        "ground_truth": "Yes, physical activity helps control blood sugar levels and improves insulin sensitivity."
    },
    {
        "question": "What is cancer?",
        "ground_truth": "I cannot find sufficient information in the provided documents."
    }
]
